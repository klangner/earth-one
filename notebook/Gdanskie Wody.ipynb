# %% [markdown]
# # Gdanskie Wody

# %%
import numpy as np
import pandas as pd
from bokeh.plotting import figure, output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Prepare data

# %%
channel_names = ['rain', 'water', 'winddir', 'windlevel', 'temp', 'pressure', 'humidity', 'sun']
stations = pd.read_csv('../data/gdanskiewody/stations.csv')
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   no         107 non-null    int64
#  1   name       107 non-null    object
#  2   active     107 non-null    bool
#  3   rain       107 non-null    bool
#  4   water      107 non-null    bool
#  5   winddir    107 non-null    bool
#  6   windlevel  107 non-null    bool
#  7   temp       107 non-null    bool
#  8   pressure   107 non-null    bool
#  9   humidity   107 non-null    bool
#  10  sun        107 non-null    bool
# dtypes: bool(9), int64(1), object(1)
# memory usage: 2.7+ KB

# %% [markdown]
# We are only interested in water stations

# %%
water_stations = stations[stations.water]
water_stations
# Out:
#       no                 name  active   rain  water  winddir  windlevel  \
# 3    251      Jana Pawła II H    True  False   True    False      False
# 4    255        M.Wisła Stogi    True  False   True    False      False
# 5    254              Port Pn    True  False   True    False      False
# 6    201      Zb. Orłowska II    True  False   True    False      False
# 7    215    Zb. 1 Jelitkowska    True  False   True    False      False
# ..   ...                  ...     ...    ...    ...      ...        ...
# 102   14           Matemblewo    True  False   True    False      False
# 103   21      Zbiornik Jasień    True  False   True    False      False
# 104   13  Matemblewo przepust    True  False   True    False      False
# 105   25   Zbiornik Kiełpinek    True  False   True    False      False
# 106   40      Matarnicki Pot.    True  False   True    False      False
#
#       temp  pressure  humidity    sun
# 3    False     False     False  False
# ...

# %%
channel = pd.read_csv('../data/gdanskiewody/13-water.csv', index_col=0, parse_dates=True).water
channel.head()
# Out:
# time
# 2015-08-10 10:00:00    0.00
# 2015-08-10 13:00:00    0.00
# 2015-09-09 11:00:00    1.07
# 2015-09-09 12:00:00    0.35
# 2015-09-09 13:00:00    0.34
# Name: water, dtype: float64

# %%
p = figure()
p.circle(channel.index, channel.values, size=1)
show(p)
# Out:
#   <div class="bk-root" id="b03af63c-3ae2-4ced-b65d-7964cfcbdea3" data-root-id="1765"></div>
